# %%
## comment

# explore the data from OCP

# %%
## import

import pandas as pd
import numpy as np
import random
import ray
from itertools import combinations
import torch.nn as nn
import torch
import math
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, ElasticNet
from sklearn.kernel_ridge import KernelRidge
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')
from sklearn.decomposition import PCA
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import sys
import os
import logging
from sklearn.model_selection import GroupShuffleSplit
from sklearn.pipeline import Pipeline
import gc
from pprint import pprint
# Out:
# 2023-10-03 19:33:59,178	INFO util.py:159 -- Outdated packages:
#   ipywidgets==7.6.5 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.

# %%
## variables 

curdir = ''
logging.basicConfig(
    filename=curdir + 'logger.log', 
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
trial_no = 0
seed = 42 + trial_no
np.random.seed(seed)
random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

# %%
####################################
## ocp
####################################

# %%
df_ocp1 = pd.read_parquet(curdir + 'datasets/ocp_reactions_info_df.parquet')

# %%
df_ocp1.head(2)
# Out:
#    bulk_id  ads_id   bulk_mpid bulk_symbols ads_symbols miller_index  shift  \
# 0     2085      29   mp-976273       Hf6Ge4     *COCH2O    [2, 1, 0]  0.022
# 1    10724      20  mp-1247259     Ca6Rh2N6       *CHCO    [1, 0, 0]  0.312
#
#     top         adsorption_site  class  ...      p758      p759      p760  \
# 0  True    [[9.3, 4.58, 26.89]]      1  ... -0.698056  0.273536  0.742442
# 1  True  [[10.54, 1.25, 22.82]]      2  ... -0.625508 -0.456795  0.304594
#
#        p761      p762      p763      p764      p765      p766      p767
# 0  0.618160  0.486411 -0.934350  0.204278  0.679431  0.341144 -0.852883
# 1  1.134157 -0.394405 -1.171003 -0.648138 -0.021550 -1.443121  0.004959
#
# [2 rows x 793 columns]

# %%
def convert_to_int(x):
    try:
        return str(''.join(map(str, x)))
    except ValueError:
        print(f"Error with value: {x}")
        logging.info(f"Error with value: {x}")
        return x

df_ocp1.rename(columns={'energy': 'nre'}, inplace=True)
df_ocp1['miller_index'] = df_ocp1['miller_index'].apply(convert_to_int)
list_scols = ['s' + str(i) for i in range(9)]
list_pcols = ['p' + str(i) for i in range(768)]
list_cols = ['anomaly', 'bulk_mpid', 'miller_index'] + list_scols + list_pcols + ['nre']

# %%
df_ocp1 = df_ocp1[list_cols]

# %%
print(df_ocp1.shape)
# Out:
# (437781, 781)

# %%
print(df_ocp1.columns)

# %%
df_ocp1.head(2)
# Out:
#    anomaly   bulk_mpid miller_index        s0        s1        s2        s3  \
# 0        1   mp-976273          210  0.008258  1.035261  1.294881  1.552592
# 1        0  mp-1247259          100  0.005488  0.162778  0.328713  1.856944
#
#          s4        s5        s6  ...      p759      p760      p761      p762  \
# 0  1.783934  1.012493  2.079694  ...  0.273536  0.742442  0.618160  0.486411
# 1  1.908573  1.835093  1.429667  ... -0.456795  0.304594  1.134157 -0.394405
#
#        p763      p764      p765      p766      p767       nre
# 0 -0.934350  0.204278  0.679431  0.341144 -0.852883 -9.992999
# 1 -1.171003 -0.648138 -0.021550 -1.443121  0.004959 -9.982733
#
# [2 rows x 781 columns]

# %%
# 1. Data Preparation:

# %%
cases = {
    'case_1': [0],
    'case_2': [0,1],
    'case_3': [0,1,2],
    'case_4': [0,1,2,3],
    'case_5': df_ocp1['anomaly'].unique()
}
sample_counts = {}
filtered_dfs = {}
for case, values in cases.items():
    filtered_df = df_ocp1[df_ocp1['anomaly'].isin(values)]
    filtered_dfs[case] = filtered_df
    sample_counts[case] = len(filtered_df)
print(sample_counts)
# Out:
# {'case_1': 325743, 'case_2': 402184, 'case_3': 418753, 'case_4': 433989, 'case_5': 437781}

# %%
# 2. Preprocess Data:

# %%
# Function to preprocess data
def preprocess_data(train, test, use_pca=False):
    features = list(train.columns[3:-1])  # s0 to p767
    X_train = train[features]
    X_test = test[features]
    y_train = train['nre']
    y_test = test['nre']
    
    scaler = StandardScaler()
    # X_train_scaled = scaler.fit_transform(X_train)
    # X_test_scaled = scaler.transform(X_test)
    X_train_scaled = X_train
    X_test_scaled = X_test

    if use_pca:
        pca = PCA(0.9)
        X_train_scaled = pca.fit_transform(X_train_scaled)
        X_test_scaled = pca.transform(X_test_scaled)
    return X_train_scaled, X_test_scaled, y_train, y_test

# %%
# 3. Data Splitting based on groups:

# %%
# Define a function to split based on groups
def split_data(df, group_columns):
    gss = GroupShuffleSplit(n_splits=1, train_size=0.75, random_state=seed)
    for train_idx, test_idx in gss.split(df, groups=df[group_columns].astype(str).apply(lambda x: '_'.join(x), axis=1)):
        train = df.iloc[train_idx]
        test = df.iloc[test_idx]
    return train, test

train_test_splits = {}
for case, filtered_df in filtered_dfs.items():
    train, test = split_data(filtered_df, ['bulk_mpid', 'miller_index'])
    train_test_splits[case] = (train, test)
    
    # Calculate unique groups for total, train, and test datasets
    total_groups = filtered_df[['bulk_mpid', 'miller_index']].drop_duplicates().shape[0]
    train_groups = train[['bulk_mpid', 'miller_index']].drop_duplicates().shape[0]
    test_groups = test[['bulk_mpid', 'miller_index']].drop_duplicates().shape[0]

    # Print the results
    print(f"Case: {case}")
    print(f"Shape: {train.shape}, {test.shape}")    
    print(f"Total groups: {total_groups}")
    print(f"Training groups: {train_groups}")
    print(f"Testing groups: {test_groups}\n")
# Out:
# Case: case_1
# Shape: (245340, 781), (80403, 781)
# Total groups: 82841
# Training groups: 62130
# Testing groups: 20711
#
# Case: case_2
# Shape: (300663, 781), (101521, 781)
# Total groups: 87544
# Training groups: 65658
# Testing groups: 21886
#
# Case: case_3
# Shape: (313868, 781), (104885, 781)
# Total groups: 88572
# Training groups: 66429
# Testing groups: 22143
#
# Case: case_4
# Shape: (323018, 781), (110971, 781)
# Total groups: 91109
# Training groups: 68331
# Testing groups: 22778
#
# Case: case_5
# Shape: (329202, 781), (108579, 781)
# Total groups: 91298
# Training groups: 68473
# Testing groups: 22825

# %%
# 4. Model Training:

# %%
results = {}

# %%
# Models & hyperparameters
models = {
    'Ridge Regression': {
        'model': Ridge(),
        'params': {
            'alpha': [1.0],
        }
    },
    'Elastic Regression': {
        'model': ElasticNet(),
        'params': {
            'alpha': [1.0],
            'l1_ratio': [0.5]
        }
    },
    # 'Kernel Ridge Regression': {
    #     'model': KernelRidge(),
    #     'params': {
    #         'alpha': [1],
    #         'kernel': ['linear'],
    #         'degree': [3]
    #     }
    # },
    # 'Support Vector Regression': {
    #     'model': SVR(),
    #     'params': {
    #         'C': [1.0],
    #         'kernel': ['rbf'],
    #         'gamma': ['scale']
    #     }
    # }
}

# %%
# Create a function to plot and save the figures
def plot_and_save(predicted, true, case, model_name, transformation, folder='outputs'):
    plt.figure(figsize=(5, 3))
    plt.scatter(true, predicted, alpha=0.5)
    plt.xlabel('True')
    plt.ylabel('Predicted')
    plt.title(f"{case}: {model_name} ({transformation})")
    plt.grid(True)
    
    # Save the figure
    # Ensure the 'outputs' directory exists
    if not os.path.exists(curdir + folder):
        os.makedirs(curdir + folder)
    
    plt.savefig(f"{curdir}{folder}/{case}C_{model_name}_{transformation}.png")
    plt.close()

# %%
# Train and evaluate models
selected_cases = ['case_1', 'case_2', 'case_3', 'case_4', 'case_5'] 
for case, (train, test) in train_test_splits.items():
    if case not in selected_cases:  # Skip the cases not in selected_cases
        continue    
    print(f"case: {case}")
    
    #############################################################################################################################
    X_train, X_test, y_train, y_test = preprocess_data(train, test, use_pca=False) # For non-PCA version
    print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
    for model_name, model_details in models.items():
        print(model_name)
        clf = GridSearchCV(model_details['model'], model_details['params'], cv=5, scoring='neg_mean_absolute_error', n_jobs=1)
        clf.fit(X_train, y_train)    
        predicted = clf.predict(X_test)
        mae = -clf.score(X_test, y_test)
        params = clf.best_params_
        mean_target = y_test.abs().mean()
        # Store the results
        results[(case, model_name, 'non_pca')] = (mae, mean_target, params)
        
        # Plot
        plot_and_save(predicted, y_test, case, model_name, 'non_pca')
        del predicted
    del X_train, X_test, y_train, y_test
    gc.collect()
    
    #############################################################################################################################        
    X_train, X_test, y_train, y_test = preprocess_data(train, test, use_pca=True) # For PCA version
    print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)    
    for model_name, model_details in models.items():
        print(model_name)
        clf = GridSearchCV(model_details['model'], model_details['params'], cv=5, scoring='neg_mean_absolute_error', n_jobs=1)
        clf.fit(X_train, y_train)
        predicted = clf.predict(X_test)
        mae = -clf.score(X_test, y_test)
        params = clf.best_params_
        mean_target = y_test.abs().mean()
        # Store the results
        results[(case, model_name, 'pca')] = (mae, mean_target, params)
        
        # Plot
        plot_and_save(predicted, y_test, case, model_name, 'pca')
        del predicted
        
    del X_train, X_test, y_train, y_test
    gc.collect()
# Out:
# case: case_1
# (245340, 777) (80403, 777) (245340,) (80403,)
# Ridge Regression
# Elastic Regression
# (245340, 2) (80403, 2) (245340,) (80403,)
# Ridge Regression
# Elastic Regression
# case: case_2
# (300663, 777) (101521, 777) (300663,) (101521,)
# Ridge Regression
# Elastic Regression
# (300663, 2) (101521, 2) (300663,) (101521,)
# Ridge Regression
# Elastic Regression
# case: case_3
# (313868, 777) (104885, 777) (313868,) (104885,)
# Ridge Regression
# Elastic Regression
# (313868, 2) (104885, 2) (313868,) (104885,)
# Ridge Regression
# Elastic Regression
# case: case_4
# (323018, 777) (110971, 777) (323018,) (110971,)
# Ridge Regression
# Elastic Regression
# (323018, 3) (110971, 3) (323018,) (110971,)
# Ridge Regression
# Elastic Regression
# case: case_5
# (329202, 777) (108579, 777) (329202,) (108579,)
# Ridge Regression
# Elastic Regression
# (329202, 2) (108579, 2) (329202,) (108579,)
# Ridge Regression
# Elastic Regression

# %%
pprint(results)
# Out:
# {('case_1', 'Elastic Regression', 'non_pca'): (1.590556573532418,
#                                                2.0676390287505457,
#                                                {'alpha': 1.0, 'l1_ratio': 0.5}),
#  ('case_1', 'Elastic Regression', 'pca'): (1.600831633945426,
#                                            2.0676390287505457,
#                                            {'alpha': 1.0, 'l1_ratio': 0.5}),
#  ('case_1', 'Ridge Regression', 'non_pca'): (0.9961033177329959,
#                                              2.0676390287505457,
#                                              {'alpha': 1.0}),
#  ('case_1', 'Ridge Regression', 'pca'): (1.6008316339454263,
#                                          2.0676390287505457,
#                                          {'alpha': 1.0}),
#  ('case_2', 'Elastic Regression', 'non_pca'): (1.7230435601375031,
#                                                2.3012742392331154,
#                                                {'alpha': 1.0, 'l1_ratio': 0.5}),
#  ('case_2', 'Elastic Regression', 'pca'): (1.7454425230505195,
#                                            2.3012742392331154,
#                                            {'alpha': 1.0, 'l1_ratio': 0.5}),
#  ('case_2', 'Ridge Regression', 'non_pca'): (1.2614902151628464,
#                                              2.3012742392331154,
#                                              {'alpha': 1.0}),
#  ('case_2', 'Ridge Regression', 'pca'): (1.7454425230505195,
#                                          2.3012742392331154,
#                                          {'alpha': 1.0}),
#  ('case_3', 'Elastic Regression', 'non_pca'): (1.714187129312922,
#                                                2.2805082104278034,
#                                                {'alpha': 1.0, 'l1_ratio': 0.5}),
#  ('case_3', 'Elastic Regression', 'pca'): (1.7348976118152741,
#                                            2.2805082104278034,
#                                            {'alpha': 1.0, 'l1_ratio': 0.5}),
#  ('case_3', 'Ridge Regression', 'non_pca'): (1.2302373383194942,
#                                              2.2805082104278034,
#                                              {'alpha': 1.0}),
#  ('case_3', 'Ridge Regression', 'pca'): (1.7348976118152741,
#                                          2.2805082104278034,
#                                          {'alpha': 1.0}),
#  ('case_4', 'Elastic Regression', 'non_pca'): (1.7252894036573918,
#                                                2.293227427197783,
#                                                {'alpha': 1.0, 'l1_ratio': 0.5}),
#  ('case_4', 'Elastic Regression', 'pca'): (1.7462873089723532,
#                                            2.293227427197783,
#                                            {'alpha': 1.0, 'l1_ratio': 0.5}),
#  ('case_4', 'Ridge Regression', 'non_pca'): (1.2352247390175988,
#                                              2.293227427197783,
#                                              {'alpha': 1.0}),
#  ('case_4', 'Ridge Regression', 'pca'): (1.7462873089723532,
#                                          2.293227427197783,
#                                          {'alpha': 1.0}),
#  ('case_5', 'Elastic Regression', 'non_pca'): (1.7436197420706605,
#                                                2.280223709740743,
#                                                {'alpha': 1.0, 'l1_ratio': 0.5}),
#  ('case_5', 'Elastic Regression', 'pca'): (1.7608096524869172,
#                                            2.280223709740743,
#                                            {'alpha': 1.0, 'l1_ratio': 0.5}),
#  ('case_5', 'Ridge Regression', 'non_pca'): (1.2589330084205306,
#                                              2.280223709740743,
#                                              {'alpha': 1.0}),
#  ('case_5', 'Ridge Regression', 'pca'): (1.7608096524869172,
#                                          2.280223709740743,
#                                          {'alpha': 1.0})}
